# %% [markdown]
# # Data exploration

# %% [markdown]
# ## Import libraries

# %%
# Import needed libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. Load datasets

# %%
customers = pd.read_csv("../data/RAW/olist_customers_dataset.csv")
orders = pd.read_csv("../data/RAW/olist_orders_dataset.csv")
items = pd.read_csv("../data/RAW/olist_order_items_dataset.csv")
payments = pd.read_csv("../data/RAW/olist_order_payments_dataset.csv")
reviews = pd.read_csv("../data/RAW/olist_order_reviews_dataset.csv")
products = pd.read_csv("../data/RAW/olist_products_dataset.csv")
sellers = pd.read_csv("../data/RAW/olist_sellers_dataset.csv")
category = pd.read_csv("../data/RAW/product_category_name_translation.csv")
geolocation = pd.read_csv("../data/RAW/olist_geolocation_dataset.csv")

# %% [markdown]
# ## 1.1 Customers table exploration
#
# This section explores the customers dataset structure and performs an initial data quality assessment.

# %%
print("Dataset shape:")
print(customers.shape)

print("\nFirst 5 rows:")
display(customers.head())

print("\nRandom sample:")
display(customers.sample(5))
# Out:
# Dataset shape:
# (99441, 5)
#
# First 5 rows:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP
# Random sample:
#                             customer_id                customer_unique_id  \
# 79898  15df03bd579b23b85e60f0df52b82249  eb742a3b914c53d45f1a30c8e2fcd8bd
# 73998  99926e4250dfd6677d6d1c1783d8fd6b  763acdbb0aa14dcd7af34f6af4539267
# 79428  b98eec5515037585fa2083f6e6b787db  daa600f82edb736f64854f33de65233e
# 13751  db0423dd92a3e1b5b52d158f40ceb777  a2d8125361b16f316df65f4603b88e23
# 13910  1a615d890c80364a251ca3671d9589ab  e7bfaa9ce41830e085690fab3084f9cf
#
#        customer_zip_code_prefix      customer_city customer_state
# 79898                     96810  santa cruz do sul             RS
# 73998                     27523            resende             RJ
# 79428                     92425             canoas             RS
# 13751                     94155           gravatai             RS
# 13910                     11055             santos             SP

# %% [markdown]
# #### Dataset Information
#
# Check column names, data types, and the number of non-null values to identify potential data quality issues.

# %%
customers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  str
#  1   customer_unique_id        99441 non-null  str
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  str
#  4   customer_state            99441 non-null  str
# dtypes: int64(1), str(4)
# memory usage: 3.8 MB

# %% [markdown]
# #### Descriptive Statistics
#
# Analyze summary statistics for numerical variables and frequency information for categorical variables.

# %%
customers.describe()
# Out:
#        customer_zip_code_prefix
# count              99441.000000
# mean               35137.474583
# std                29797.938996
# min                 1003.000000
# 25%                11347.000000
# 50%                24416.000000
# 75%                58900.000000
# max                99990.000000

# %%
customers.describe(include="object")
# Out:
# C:\Users\81804\AppData\Local\Temp\ipykernel_21496\1913638412.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   customers.describe(include="object")
#                              customer_id                customer_unique_id  \
# count                              99441                             99441
# unique                             99441                             96096
# top     06b8999e2fba1a1fbc88172c00ba8bc7  8d50f5eadf50201ccdcedfb9e2ac8455
# freq                                   1                                17
#
#        customer_city customer_state
# count          99441          99441
# unique          4119             27
# top        sao paulo             SP
# freq           15540          41746

# %% [markdown]
# #### Missing Values
#
# Identify columns containing missing values and evaluate the data completeness of the dataset.

# %%
customers.isnull().sum()
# Out:
# customer_id                 0
# customer_unique_id          0
# customer_zip_code_prefix    0
# customer_city               0
# customer_state              0
# dtype: int64

# %% [markdown]
# #### Duplicate Records
#
# Check whether the dataset contains duplicated rows that may affect future analysis.

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Unique Values Analysis
#
# Analyze the number of unique values in each column to understand identifiers and categorical variables.

# %%
customers.nunique()
# Out:
# customer_id                 99441
# customer_unique_id          96096
# customer_zip_code_prefix    14994
# customer_city                4119
# customer_state                 27
# dtype: int64

# %% [markdown]
# ## 1.2 Orders table exploration
#
# This section explores the orders dataset structure and performs an initial data quality assessment.

# %%
print("Dataset shape:")
print(orders.shape)

print("\nFirst 5 rows:")
display(orders.head())

print("\nRandom sample:")
display(orders.sample(5))
# Out:
# Dataset shape:
# (99441, 8)
#
# First 5 rows:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00
# Random sample:
#                                order_id                       customer_id  \
# 16671  0fb5f1722ce814b29e3fb1a5286a7684  9dbbcb1bf333f98d688f0af44f2e8962
# 30821  06a3bd42be69cdf39cd785d311b54a45  9e43617117f81bfddf4b3ec7625752aa
# 3667   f8c9df743a18aeeedd550486dbe39689  ff4512b27e3f8d9774f6e01ceb951035
# 52755  48cfadf939f8bc6a5f3890799a9c62f5  35bc87103d16a383cf9a98b672d3bb3e
# 17128  943625151a5d8d00da80e96a90930e03  2953e41dea84f8fe69dc569138b6002f
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 16671    delivered      2017-08-06 16:56:13  2017-08-08 04:40:28
# 30821    delivered      2017-09-19 15:39:10  2017-09-19 15:55:40
# 3667     delivered      2018-06-07 17:52:27  2018-06-07 18:17:22
# 52755    delivered      2018-07-18 18:58:11  2018-07-19 02:55:10
# 17128     canceled      2018-02-17 09:59:29  2018-02-17 10:10:26
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 16671          2017-08-11 22:34:57           2017-08-16 18:05:02
# 30821          2017-09-19 20:53:51           2017-09-26 21:30:08
# 3667           2018-06-08 09:58:00           2018-06-19 15:58:51
# 52755          2018-07-19 15:17:00           2018-07-23 17:31:37
# 17128          2018-02-20 16:48:58                           NaN
#
#       order_estimated_delivery_date
# 16671           2017-08-18 00:00:00
# 30821           2017-10-11 00:00:00
# 3667            2018-07-11 00:00:00
# 52755           2018-08-01 00:00:00
# 17128           2018-03-06 00:00:00

# %% [markdown]
# #### Dataset Information
#
# Check column names, data types, and the number of non-null values to identify potential data quality issues.

# %%
orders.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  str
#  1   customer_id                    99441 non-null  str
#  2   order_status                   99441 non-null  str
#  3   order_purchase_timestamp       99441 non-null  str
#  4   order_approved_at              99281 non-null  str
#  5   order_delivered_carrier_date   97658 non-null  str
#  6   order_delivered_customer_date  96476 non-null  str
#  7   order_estimated_delivery_date  99441 non-null  str
# dtypes: str(8)
# memory usage: 6.1 MB

# %% [markdown]
# #### Descriptive Statistics
#
# Analyze summary statistics for numerical variables and frequency information for categorical variables.

# %%
orders.describe()
# Out:
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-03-31 15:08:21  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-14 20:02:44
# freq                             47                             3
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %%
orders.describe(include="object")
# Out:
# C:\Users\81804\AppData\Local\Temp\ipykernel_21496\3661551341.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   orders.describe(include="object")
#                                 order_id                       customer_id  \
# count                              99441                             99441
# unique                             99441                             99441
# top     e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# freq                                   1                                 1
#
#        order_status order_purchase_timestamp    order_approved_at  \
# count         99441                    99441                99281
# unique            8                    98875                90733
# top       delivered      2018-03-31 15:08:21  2018-02-27 04:31:10
# freq          96478                        3                    9
#
#        order_delivered_carrier_date order_delivered_customer_date  \
# count                         97658                         96476
# unique                        81018                         95664
# top             2018-05-09 15:48:00           2018-05-14 20:02:44
# freq                             47                             3
#
#        order_estimated_delivery_date
# count                          99441
# unique                           459
# top              2017-12-20 00:00:00
# freq                             522

# %% [markdown]
# #### Missing Values
#
# Identify columns containing missing values and evaluate the data completeness of the dataset.

# %%
orders.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# order_estimated_delivery_date       0
# dtype: int64

# %% [markdown]
# #### Duplicate Records
#
# Check whether the dataset contains duplicated rows that may affect future analysis.

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Unique Values Analysis
#
# Analyze the number of unique values in each column to understand identifiers and categorical variables.

# %%
orders.nunique()
# Out:
# order_id                         99441
# customer_id                      99441
# order_status                         8
# order_purchase_timestamp         98875
# order_approved_at                90733
# order_delivered_carrier_date     81018
# order_delivered_customer_date    95664
# order_estimated_delivery_date      459
# dtype: int64

# %% [markdown]
# ## 1.3 Items table exploration
#
# This section explores the items dataset structure and performs an initial data quality assessment.

# %%
print("Dataset shape:")
print(items.shape)

print("\nFirst 5 rows:")
display(items.head())

print("\nRandom sample:")
display(items.sample(5))
# Out:
# Dataset shape:
# (112650, 7)
#
# First 5 rows:
#                            order_id  order_item_id  \
# 0  00010242fe8c5a6d1ba2dd792cb16214              1
# 1  00018f77f2f0320c557190d7a144bdd3              1
# 2  000229ec398224ef6ca0657da4fc703e              1
# 3  00024acbcdf0a6daa1e931b038114c75              1
# 4  00042b26cf59d7ce69dfabb4e55b4fd9              1
#
#                          product_id                         seller_id  \
# 0  4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1  e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2  c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3  7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4  ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
#
#    shipping_limit_date   price  freight_value
# 0  2017-09-19 09:45:35   58.90          13.29
# 1  2017-05-03 11:05:13  239.90          19.93
# 2  2018-01-18 14:48:30  199.00          17.87
# 3  2018-08-15 10:10:18   12.99          12.79
# 4  2017-02-13 13:57:51  199.90          18.14
# Random sample:
#                                order_id  order_item_id  \
# 2761   063bbb83c80ba8c04934c9ff389be77a              1
# 23991  36a924d21368a46d4ed120b8adb1dc3d              1
# 90899  ce7be9c906c372368c7786881d6a6842              1
# 4127   0942763b4318676d85b3185d80f57cd3              1
# 30041  443a73a22cd4e0078a47c275b358b786              1
#
#                              product_id                         seller_id  \
# 2761   ee0c1cf2fbeae95205b4aa506f1469f0  cc419e0650a3c5ba77189a1882b7556a
# 23991  fb3ac05315c8f4a1b54de74e098ef7e2  16090f2ca825584b5a147ab24aa30c86
# 90899  d1c427060a0f73f6b889a5c7c61f2ac4  a1043bafd471dff536d0c462352beb48
# 4127   cbb702235ad267cca951499fa8475606  59fb871bf6f4522a87ba567b42dafecf
# 30041  90c3564fa89e67d5e1b4898dd43cebc9  2c9e548be18521d1c43cde1c582c6de8
#
#        shipping_limit_date   price  freight_value
# 2761   2018-02-14 09:09:39   53.99          15.13
# 23991  2018-06-27 10:55:13  649.49          23.74
# 90899  2018-02-02 14:51:18  149.00          45.12
# 4127   2017-09-20 14:50:07  249.99          17.19
# 30041  2018-05-18 12:31:08   25.90          18.23

# %% [markdown]
# #### Dataset Information
#
# Check column names, data types, and the number of non-null values to identify potential data quality issues.

# %%
items.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  str
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  str
#  3   seller_id            112650 non-null  str
#  4   shipping_limit_date  112650 non-null  str
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), str(4)
# memory usage: 6.0 MB

# %% [markdown]
# #### Descriptive Statistics
#
# Analyze summary statistics for numerical variables and frequency information for categorical variables.

# %%
items.describe()
# Out:
#        order_item_id          price  freight_value
# count  112650.000000  112650.000000  112650.000000
# mean        1.197834     120.653739      19.990320
# std         0.705124     183.633928      15.806405
# min         1.000000       0.850000       0.000000
# 25%         1.000000      39.900000      13.080000
# 50%         1.000000      74.990000      16.260000
# 75%         1.000000     134.900000      21.150000
# max        21.000000    6735.000000     409.680000

# %%
items.describe(include="object")
# Out:
# C:\Users\81804\AppData\Local\Temp\ipykernel_21496\2471809359.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   items.describe(include="object")
#                                 order_id                        product_id  \
# count                             112650                            112650
# unique                             98666                             32951
# top     8272b63d03f5f79c56e9e4120aec44ef  aca2eb7d00ea1a7b8ebd4e68314663af
# freq                                  21                               527
#
#                                seller_id  shipping_limit_date
# count                             112650               112650
# unique                              3095                93318
# top     6560211a19b47992c3666cc44a7e94c0  2018-03-01 02:50:48
# freq                                2033                   21

# %% [markdown]
# #### Missing Values
#
# Identify columns containing missing values and evaluate the data completeness of the dataset.

# %%
items.isnull().sum()
# Out:
# order_id               0
# order_item_id          0
# product_id             0
# seller_id              0
# shipping_limit_date    0
# price                  0
# freight_value          0
# dtype: int64

# %% [markdown]
# #### Duplicate Records
#
# Check whether the dataset contains duplicated rows that may affect future analysis.

# %%
items.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Unique Values Analysis
#
# Analyze the number of unique values in each column to understand identifiers and categorical variables.

# %%
items.nunique()
# Out:
# order_id               98666
# order_item_id             21
# product_id             32951
# seller_id               3095
# shipping_limit_date    93318
# price                   5968
# freight_value           6999
# dtype: int64

# %% [markdown]
# ## 1.4 Payments table exploration
#
# This section explores the payments dataset structure and performs an initial data quality assessment.

# %%
print("Dataset shape:")
print(payments.shape)

print("\nFirst 5 rows:")
display(payments.head())

print("\nRandom sample:")
display(payments.sample(5))
# Out:
# Dataset shape:
# (103886, 5)
#
# First 5 rows:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45
# Random sample:
#                                order_id  payment_sequential payment_type  \
# 37139  eeb4d23ba9fb9cb0897472f49f332505                   1  credit_card
# 34002  a1e393fb70c2916de4f93974682521a0                   1  credit_card
# 43408  3341c1471465b4198ac0c139659da90f                   1       boleto
# 43370  66057d37308e787052a32828cd007e58                   1  credit_card
# 16862  369423839b4d9789d69665b7c2361443                   1       boleto
#
#        payment_installments  payment_value
# 37139                     2         138.15
# 34002                     7          72.07
# 43408                     1          70.75
# 43370                     1          32.39
# 16862                     1         331.58

# %% [markdown]
# #### Dataset Information
#
# Check column names, data types, and the number of non-null values to identify potential data quality issues.

# %%
payments.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  str
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  str
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), str(2)
# memory usage: 4.0 MB

# %% [markdown]
# #### Descriptive Statistics
#
# Analyze summary statistics for numerical variables and frequency information for categorical variables.

# %%
payments.describe()
# Out:
#        payment_sequential  payment_installments  payment_value
# count       103886.000000         103886.000000  103886.000000
# mean             1.092679              2.853349     154.100380
# std              0.706584              2.687051     217.494064
# min              1.000000              0.000000       0.000000
# 25%              1.000000              1.000000      56.790000
# 50%              1.000000              1.000000     100.000000
# 75%              1.000000              4.000000     171.837500
# max             29.000000             24.000000   13664.080000

# %%
payments.describe(include="object")
# Out:
# C:\Users\81804\AppData\Local\Temp\ipykernel_21496\166784764.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   payments.describe(include="object")
#                                 order_id payment_type
# count                             103886       103886
# unique                             99440            5
# top     fa65dad1b0e818e3ccc5cb0e39231352  credit_card
# freq                                  29        76795

# %% [markdown]
# #### Missing Values
#
# Identify columns containing missing values and evaluate the data completeness of the dataset.

# %%
payments.isnull().sum()
# Out:
# order_id                0
# payment_sequential      0
# payment_type            0
# payment_installments    0
# payment_value           0
# dtype: int64

# %% [markdown]
# #### Duplicate Records
#
# Check whether the dataset contains duplicated rows that may affect future analysis.

# %%
payments.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Unique Values Analysis
#
# Analyze the number of unique values in each column to understand identifiers and categorical variables.

# %%
payments.nunique()
# Out:
# order_id                99440
# payment_sequential         29
# payment_type                5
# payment_installments       24
# payment_value           29077
# dtype: int64

# %% [markdown]
# ## 1.5 Reviews table exploration
#
# This section explores the reviews dataset structure and performs an initial data quality assessment.

# %%
print("Dataset shape:")
print(reviews.shape)

print("\nFirst 5 rows:")
display(reviews.head())

print("\nRandom sample:")
display(reviews.sample(5))
# Out:
# Dataset shape:
# (99224, 7)
#
# First 5 rows:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53
# Random sample:
#                               review_id                          order_id  \
# 68520  4f330ad9d3624523c14d694928188ce1  be40003fbcabb63c85ff36dc4a85b5be
# 12462  57bfc0d2586e151424a6412c045ea5b1  4e801b3860564f02745ba49a886fbc0d
# 8506   767842293da7e287c70162b12bc46609  e94463ec887705d951724d52248d7855
# 35563  ffaf83e3350ca02b32c119c2bcf98ec8  cad95e56b8bc5ed2c10ee964ba21ac96
# 75231  c86306c2bf2f5c62cf71f4bfdf75b437  b3448645d567afb9a105a91748a9e2ab
#
#        review_score review_comment_title  \
# 68520             1                  NaN
# 12462             3           RECOMENDO
# 8506              3  Defeito do produto
# 35563             2                  NaN
# 75231             5                  NaN
#
#                                   review_comment_message review_creation_date  \
# 68520  Meu produto foi devolvido pelo os correio e a ...  2018-04-22 00:00:00
# 12462  BOA QUALIDADE SÓ Q O MULINETE É MUITO SIMPLES ...  2018-05-10 00:00:00
# 8506                          O Ilhos veio com defeito.   2018-06-20 00:00:00
# 35563                                                NaN  2018-03-21 00:00:00
# 75231                                                NaN  2018-04-24 00:00:00
#
#       review_answer_timestamp
# 68520     2018-04-22 14:20:14
# 12462     2018-05-14 15:08:52
# 8506      2018-06-22 22:23:49
# 35563     2018-03-21 12:52:32
# 75231     2018-04-25 00:05:47

# %% [markdown]
# #### Dataset Information
#
# Check column names, data types, and the number of non-null values to identify potential data quality issues.

# %%
reviews.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 99224 entries, 0 to 99223
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   review_id                99224 non-null  str
#  1   order_id                 99224 non-null  str
#  2   review_score             99224 non-null  int64
#  3   review_comment_title     11568 non-null  str
#  4   review_comment_message   40977 non-null  str
#  5   review_creation_date     99224 non-null  str
#  6   review_answer_timestamp  99224 non-null  str
# dtypes: int64(1), str(6)
# memory usage: 5.3 MB

# %% [markdown]
# #### Descriptive Statistics
#
# Analyze summary statistics for numerical variables and frequency information for categorical variables.

# %%
reviews.describe()
# Out:
#        review_score
# count  99224.000000
# mean       4.086421
# std        1.347579
# min        1.000000
# 25%        4.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
reviews.describe(include="object")
# Out:
# C:\Users\81804\AppData\Local\Temp\ipykernel_21496\3547632400.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   reviews.describe(include="object")
#                                review_id                          order_id  \
# count                              99224                             99224
# unique                             98410                             98673
# top     c444278834184f72b1484dfe47de7f97  c88b1d1b157a9999ce368f218a407141
# freq                                   3                                 3
#
#        review_comment_title review_comment_message review_creation_date  \
# count                 11568                  40977                99224
# unique                 4527                  36159                  636
# top               Recomendo              Muito bom  2017-12-19 00:00:00
# freq                    423                    230                  463
#
#        review_answer_timestamp
# count                    99224
# unique                   98248
# top        2017-06-15 23:21:05
# freq                         4

# %% [markdown]
# #### Missing Values
#
# Identify columns containing missing values and evaluate the data completeness of the dataset.

# %%
reviews.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       87656
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %% [markdown]
# #### Duplicate Records
#
# Check whether the dataset contains duplicated rows that may affect future analysis.

# %%
reviews.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Unique Values Analysis
#
# Analyze the number of unique values in each column to understand identifiers and categorical variables.

# %%
reviews.nunique()
# Out:
# review_id                  98410
# order_id                   98673
# review_score                   5
# review_comment_title        4527
# review_comment_message     36159
# review_creation_date         636
# review_answer_timestamp    98248
# dtype: int64

# %% [markdown]
# ## 1.6 Products table exploration
#
# This section explores the products dataset structure and performs an initial data quality assessment.

# %%
print("Dataset shape:")
print(products.shape)

print("\nFirst 5 rows:")
display(products.head())

print("\nRandom sample:")
display(products.sample(5))
# Out:
# Dataset shape:
# (32951, 9)
#
# First 5 rows:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# 1            1000.0               30.0               18.0              20.0
# 2             154.0               18.0                9.0              15.0
# 3             371.0               26.0                4.0              26.0
# 4             625.0               20.0               17.0              13.0
# Random sample:
#                              product_id   product_category_name  \
# 19158  1cb60c9b90bc722828facc251de1cf94   utilidades_domesticas
# 1906   47f4c1c7335bd22493bf6f376ee9fa6b            beleza_saude
# 160    1ffe365aa7583189e63f2fa4f060b269           esporte_lazer
# 19574  4ebb7da18bd79f78995f5eb2243203e1           esporte_lazer
# 13497  3742ea63675dd01004c7dd8a3cd46d48  informatica_acessorios
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 19158                 51.0                       684.0                 1.0
# 1906                  57.0                       721.0                 1.0
# 160                   57.0                       785.0                 4.0
# 19574                 57.0                        58.0                 3.0
# 13497                 38.0                      1346.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 19158            9350.0               40.0               35.0
# 1906              560.0               20.0               12.0
# 160              5200.0               20.0               60.0
# 19574            4800.0               20.0               40.0
# 13497             900.0               31.0               13.0
#
#        product_width_cm
# 19158              40.0
# 1906               16.0
# 160                35.0
# 19574              30.0
# 13497              11.0

# %% [markdown]
# #### Dataset Information
#
# Check column names, data types, and the number of non-null values to identify potential data quality issues.

# %%
products.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  str
#  1   product_category_name       32341 non-null  str
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), str(2)
# memory usage: 2.3 MB

# %% [markdown]
# #### Descriptive Statistics
#
# Analyze summary statistics for numerical variables and frequency information for categorical variables.

# %%
products.describe()
# Out:
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# count         32341.000000                32341.000000        32341.000000
# mean             48.476949                  771.495285            2.188986
# std              10.245741                  635.115225            1.736766
# min               5.000000                    4.000000            1.000000
# 25%              42.000000                  339.000000            1.000000
# 50%              51.000000                  595.000000            1.000000
# 75%              57.000000                  972.000000            3.000000
# max              76.000000                 3992.000000           20.000000
#
#        product_weight_g  product_length_cm  product_height_cm  \
# count      32949.000000       32949.000000       32949.000000
# mean        2276.472488          30.815078          16.937661
# std         4282.038731          16.914458          13.637554
# min            0.000000           7.000000           2.000000
# 25%          300.000000          18.000000           8.000000
# 50%          700.000000          25.000000          13.000000
# 75%         1900.000000          38.000000          21.000000
# max        40425.000000         105.000000         105.000000
#
#        product_width_cm
# count      32949.000000
# mean          23.196728
# std           12.079047
# min            6.000000
# 25%           15.000000
# 50%           20.000000
# 75%           30.000000
# max          118.000000

# %%
products.describe(include="object")
# Out:
# C:\Users\81804\AppData\Local\Temp\ipykernel_21496\2778178033.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   products.describe(include="object")
#                               product_id product_category_name
# count                              32951                 32341
# unique                             32951                    73
# top     1e9e8ef04dbcff4541ed26657ea517e5       cama_mesa_banho
# freq                                   1                  3029

# %% [markdown]
# #### Missing Values
#
# Identify columns containing missing values and evaluate the data completeness of the dataset.

# %%
products.isnull().sum()
# Out:
# product_id                      0
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64

# %% [markdown]
# #### Duplicate Records
#
# Check whether the dataset contains duplicated rows that may affect future analysis.

# %%
products.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Unique Values Analysis
#
# Analyze the number of unique values in each column to understand identifiers and categorical variables.

# %%
products.nunique()
# Out:
# product_id                    32951
# product_category_name            73
# product_name_lenght              66
# product_description_lenght     2960
# product_photos_qty               19
# product_weight_g               2204
# product_length_cm                99
# product_height_cm               102
# product_width_cm                 95
# dtype: int64

# %% [markdown]
# ## 1.7 Sellers table exploration
#
# This section explores the sellers dataset structure and performs an initial data quality assessment.

# %%
print("Dataset shape:")
print(sellers.shape)

print("\nFirst 5 rows:")
display(sellers.head())

print("\nRandom sample:")
display(sellers.sample(5))
# Out:
# Dataset shape:
# (3095, 4)
#
# First 5 rows:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP
# Random sample:
#                              seller_id  seller_zip_code_prefix  \
# 1278  661ad5fcc28cdfb8bcadb12bb2272475                   88330
# 2036  54a1852d1b8f10312c55e906355666ee                   13456
# 2268  cee48807215b30a12ca2ca10ffb5f250                   11431
# 1984  5d3bb11474a06bdc23fb9e89f1164ee0                   19804
# 678   aec99834ab5d38ead22766ada8497e87                   83411
#
#                 seller_city seller_state
# 1278     balneario camboriu           SC
# 2036  santa barbara d'oeste           SP
# 2268                guaruja           SP
# 1984                  assis           SP
# 678                 colombo           PR

# %% [markdown]
# #### Dataset Information
#
# Check column names, data types, and the number of non-null values to identify potential data quality issues.

# %%
sellers.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   str
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   str
#  3   seller_state            3095 non-null   str
# dtypes: int64(1), str(3)
# memory usage: 96.8 KB

# %% [markdown]
# #### Descriptive Statistics
#
# Analyze summary statistics for numerical variables and frequency information for categorical variables.

# %%
sellers.describe()
# Out:
#        seller_zip_code_prefix
# count             3095.000000
# mean             32291.059451
# std              32713.453830
# min               1001.000000
# 25%               7093.500000
# 50%              14940.000000
# 75%              64552.500000
# max              99730.000000

# %%
sellers.describe(include="object")
# Out:
# C:\Users\81804\AppData\Local\Temp\ipykernel_21496\1113468275.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   sellers.describe(include="object")
#                                seller_id seller_city seller_state
# count                               3095        3095         3095
# unique                              3095         611           23
# top     3442f8959a84dea7ee197c632cb2df15   sao paulo           SP
# freq                                   1         694         1849

# %% [markdown]
# #### Missing Values
#
# Identify columns containing missing values and evaluate the data completeness of the dataset.

# %%
sellers.isnull().sum()
# Out:
# seller_id                 0
# seller_zip_code_prefix    0
# seller_city               0
# seller_state              0
# dtype: int64

# %% [markdown]
# #### Duplicate Records
#
# Check whether the dataset contains duplicated rows that may affect future analysis.

# %%
sellers.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Unique Values Analysis
#
# Analyze the number of unique values in each column to understand identifiers and categorical variables.

# %%
sellers.nunique()
# Out:
# seller_id                 3095
# seller_zip_code_prefix    2246
# seller_city                611
# seller_state                23
# dtype: int64

# %% [markdown]
# ## 1.8 Category table exploration
#
# This section explores the category dataset structure and performs an initial data quality assessment.

# %%
print("Dataset shape:")
print(category.shape)

print("\nFirst 5 rows:")
display(category.head())

print("\nRandom sample:")
display(category.sample(5))
# Out:
# Dataset shape:
# (71, 2)
#
# First 5 rows:
#     product_category_name product_category_name_english
# 0            beleza_saude                 health_beauty
# 1  informatica_acessorios         computers_accessories
# 2              automotivo                          auto
# 3         cama_mesa_banho                bed_bath_table
# 4        moveis_decoracao               furniture_decor
# Random sample:
#                  product_category_name product_category_name_english
# 28             fashion_roupa_masculina         fashion_male_clothing
# 51                     fashion_esporte                 fashion_sport
# 37           agro_industria_e_comercio    agro_industry_and_commerce
# 57                   livros_importados                books_imported
# 36  construcao_ferramentas_ferramentas       costruction_tools_tools

# %% [markdown]
# #### Dataset Information
#
# Check column names, data types, and the number of non-null values to identify potential data quality issues.

# %%
category.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 71 entries, 0 to 70
# Data columns (total 2 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   product_category_name          71 non-null     str
#  1   product_category_name_english  71 non-null     str
# dtypes: str(2)
# memory usage: 1.2 KB

# %% [markdown]
# #### Descriptive Statistics
#
# Analyze summary statistics for numerical variables and frequency information for categorical variables.

# %%
category.describe()
# Out:
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %%
category.describe(include="object")
# Out:
# C:\Users\81804\AppData\Local\Temp\ipykernel_21496\1839052779.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   category.describe(include="object")
#        product_category_name product_category_name_english
# count                     71                            71
# unique                    71                            71
# top             beleza_saude                 health_beauty
# freq                       1                             1

# %% [markdown]
# #### Missing Values
#
# Identify columns containing missing values and evaluate the data completeness of the dataset.

# %%
category.isnull().sum()
# Out:
# product_category_name            0
# product_category_name_english    0
# dtype: int64

# %% [markdown]
# #### Duplicate Records
#
# Check whether the dataset contains duplicated rows that may affect future analysis.

# %%
category.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Unique Values Analysis
#
# Analyze the number of unique values in each column to understand identifiers and categorical variables.

# %%
category.nunique()
# Out:
# product_category_name            71
# product_category_name_english    71
# dtype: int64

# %% [markdown]
# ## 1.9 Geolocation table exploration
#
# This section explores the geolocation dataset structure and performs an initial data quality assessment.

# %%
print("Dataset shape:")
print(geolocation.shape)

print("\nFirst 5 rows:")
display(geolocation.head())

print("\nRandom sample:")
display(geolocation.sample(5))
# Out:
# Dataset shape:
# (1000163, 5)
#
# First 5 rows:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP
# Random sample:
#         geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 924777                        89170       -27.217584       -49.729017
# 586790                        35160       -19.508033       -42.562540
# 549718                        30315       -19.952916       -43.936868
# 266448                        11950       -24.735161       -48.110647
# 968854                        95560       -29.335209       -49.733482
#
#        geolocation_city geolocation_state
# 924777       laurentino                SC
# 586790         ipatinga                MG
# 549718   belo horizonte                MG
# 266448           cajati                SP
# 968854           torres                RS

# %% [markdown]
# #### Dataset Information
#
# Check column names, data types, and the number of non-null values to identify potential data quality issues.

# %%
geolocation.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  str
#  4   geolocation_state            1000163 non-null  str
# dtypes: float64(2), int64(1), str(2)
# memory usage: 38.2 MB

# %% [markdown]
# #### Descriptive Statistics
#
# Analyze summary statistics for numerical variables and frequency information for categorical variables.

# %%
geolocation.describe()
# Out:
#        geolocation_zip_code_prefix  geolocation_lat  geolocation_lng
# count                 1.000163e+06     1.000163e+06     1.000163e+06
# mean                  3.657417e+04    -2.117615e+01    -4.639054e+01
# std                   3.054934e+04     5.715866e+00     4.269748e+00
# min                   1.001000e+03    -3.660537e+01    -1.014668e+02
# 25%                   1.107500e+04    -2.360355e+01    -4.857317e+01
# 50%                   2.653000e+04    -2.291938e+01    -4.663788e+01
# 75%                   6.350400e+04    -1.997962e+01    -4.376771e+01
# max                   9.999000e+04     4.506593e+01     1.211054e+02

# %%
geolocation.describe(include="object")
# Out:
# C:\Users\81804\AppData\Local\Temp\ipykernel_21496\2386870308.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   geolocation.describe(include="object")
#        geolocation_city geolocation_state
# count           1000163           1000163
# unique             8011                27
# top           sao paulo                SP
# freq             135800            404268

# %% [markdown]
# #### Missing Values
#
# Identify columns containing missing values and evaluate the data completeness of the dataset.

# %%
geolocation.isnull().sum()
# Out:
# geolocation_zip_code_prefix    0
# geolocation_lat                0
# geolocation_lng                0
# geolocation_city               0
# geolocation_state              0
# dtype: int64

# %% [markdown]
# #### Duplicate Records
#
# Check whether the dataset contains duplicated rows that may affect future analysis.

# %%
geolocation.duplicated().sum()
# Out:
# np.int64(261831)

# %% [markdown]
# #### Unique Values Analysis
#
# Analyze the number of unique values in each column to understand identifiers and categorical variables.

# %%
geolocation.nunique()
# Out:
# geolocation_zip_code_prefix     19015
# geolocation_lat                717360
# geolocation_lng                717613
# geolocation_city                 8011
# geolocation_state                  27
# dtype: int64

# %% [markdown]
# ## Initial Findings
#
# During the initial exploration of the Olist datasets, the following observations were identified:
#
# - The datasets have a relational structure connected mainly through order_id, customer_id, product_id, and seller_id.
# - Some columns require data type conversion, especially timestamp columns.
# - Missing values exist in some datasets and will require further investigation.
# - The orders dataset contains important information about purchase status and delivery dates.
# - The order_items and payments datasets will be essential for revenue analysis.
# - The geolocation dataset contains a large number of records and may require additional processing.
